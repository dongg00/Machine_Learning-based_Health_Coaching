# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore")
pd.set_option('display.max_columns', None)
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import resample
from sklearn.impute import KNNImputer
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, VotingClassifier, HistGradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# %%
data = pd.read_csv("C:/semi_project/health_checkup/JDM/선택컬럼_건강데이터.csv")

# %%
data
# Out:
#               ID    year  region  town_t  sex   age  incm  ho_incm  edu  occp  \
# 0     YA84208301  2023.0     1.0     1.0  1.0  75.0   3.0      2.0  1.0   7.0
# 1     YA84208302  2023.0     1.0     1.0  2.0  70.0   3.0      2.0  1.0   7.0
# 2     YA84212402  2023.0     1.0     1.0  2.0  42.0   2.0      3.0  3.0   3.0
# 3     YA84212404  2023.0     1.0     1.0  2.0   9.0   2.0      3.0  1.0   NaN
# 4     YA84242702  2023.0     1.0     1.0  1.0  43.0   4.0      4.0  4.0   1.0
# ...          ...     ...     ...     ...  ...   ...   ...      ...  ...   ...
# 6924  YR62368101  2023.0     8.0     2.0  1.0  80.0   2.0      1.0  1.0   7.0
# 6925  YR62368102  2023.0     8.0     2.0  2.0  78.0   2.0      1.0  1.0   7.0
# 6926  YR62370201  2023.0     8.0     2.0  2.0  61.0   1.0      1.0  3.0   3.0
# 6927  YR62394401  2023.0     8.0     2.0  1.0  57.0   4.0      4.0  4.0   2.0
# 6928  YR62432901  2023.0     8.0     2.0  1.0  49.0   3.0      4.0  3.0   5.0
#
# ...

# %%
filtered_data4 = data[(data['DE1_3'] == 2) & (data['DE1_3'].notna())] #//당뇨 관리 안함

# %%
filtered_data4["HE_glu"].mean()
# Out:
# np.float64(149.92307692307693)

# %%
data = data[data['DE1_3'].isin([1, 2])]

# %%
data = data[data['DI1_pt'].isin([0, 1])]

# %%
filtered_data5 = data[(data['DE1_3'] == 1) & (data['DE1_3'].notna())] #//당뇨 관리 함

# %%
filtered_data5["HE_glu"].mean()
# Out:
# np.float64(131.67981790591807)

# %%
filtered_data2 = data[(data['DI1_pt'] == 0) & (data['DI1_pt'].notna())] #//혈압 치료 안 함

# %%
filtered_data2["DI1_pt"]
# Out:
# 115     0.0
# 181     0.0
# 335     0.0
# 376     0.0
# 380     0.0
#        ...
# 6652    0.0
# 6665    0.0
# 6733    0.0
# 6797    0.0
# 6798    0.0
# Name: DI1_pt, Length: 98, dtype: float64

# %%
filtered_data2["HE_dbp1"].mean()
# Out:
# np.float64(82.61855670103093)

# %%
filtered_data3["HE_dbp1"].mean()
# Out:
# np.float64(76.78302488832163)

# %%
filtered_data2["HE_sbp1"]
# Out:
# 115     109.0
# 181     131.0
# 335     135.0
# 376     170.0
# 380     142.0
#         ...
# 6652    137.0
# 6665    121.0
# 6733    159.0
# 6797    142.0
# 6798    160.0
# Name: HE_sbp1, Length: 98, dtype: float64

# %%
filtered_data3 = data[(data['DI1_pt'] == 1) & (data['DI1_pt'].notna())] #혈압  치료 함

# %%
filtered_data3["DI1_pt"]
# Out:
# 0       1.0
# 15      1.0
# 32      1.0
# 40      1.0
# 57      1.0
#        ...
# 6918    1.0
# 6922    1.0
# 6923    1.0
# 6924    1.0
# 6925    1.0
# Name: DI1_pt, Length: 1584, dtype: float64

# %%
filtered_data3["HE_sbp1"]
# Out:
# 0       144.0
# 15      115.0
# 32      125.0
# 40      132.0
# 57      132.0
#         ...
# 6918    139.0
# 6922    119.0
# 6923    107.0
# 6924    117.0
# 6925    136.0
# Name: HE_sbp1, Length: 1584, dtype: float64

# %%
filtered_data3["HE_sbp1"].mean()
# Out:
# np.float64(130.040842373963)

# %%
filtered_data2["HE_sbp1"].mean()
# Out:
# np.float64(134.64948453608247)
